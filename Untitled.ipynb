# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os
import sys

# %%
img1 = cv2.imread("workspace/images/img1.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(img1, cmap='gray')
plt.show()

img2 = cv2.imread("workspace/images/img2.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(img2, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-4a45bad291f8> in <module>
#       1 img1 = cv2.imread("workspace/images/img1.jpg", cv2.IMREAD_GRAYSCALE)
# ----> 2 plt.imshow(img1, cmap='gray')
#       3 plt.show()
#       4
#       5 img2 = cv2.imread("workspace/images/img2.jpg", cv2.IMREAD_GRAYSCALE)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5613                               resample=resample, **kwargs)
#    5614
# -> 5615         im.set_data(X)
#    5616         im.set_alpha(alpha)
#    5617         if im.get_clip_path() is None:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     692                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     693             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 694                             "float".format(self._A.dtype))
#     695
#     696         if not (self._A.ndim == 2
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
MAX_FEATURES = 5000

# creating the ORB feature extractor
orb = cv2.ORB_create(MAX_FEATURES)

# creating feature points for first and second images
kp1, dc1 = orb.detectAndCompute(img1, None)
kp2, dc2 = orb.detectAndCompute(img2, None)

img1_ORB = cv2.drawKeypoints(img1, kp1, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(img1_ORB)
plt.show()

# %%
GOOD_MATCH_PERCENT = 0.2

# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

# match descriptors
matches = bf.match(dc1, dc2)

# Sort matches by score
matches.sort(key=lambda x: x.distance, reverse=False)

# Remove worst matches
numGoodMatches = int(len(matches) * GOOD_MATCH_PERCENT)
matches = matches[:numGoodMatches]

img_match = cv2.drawMatches(img1,kp1,img2,kp2,matches,None, flags=2)
plt.imshow(img_match)
plt.show()

pts1 = np.float32([ kp1[m.queryIdx].pt for m in matches ]).reshape(-1,1,2)
pts2 = np.float32([ kp2[m.trainIdx].pt for m in matches ]).reshape(-1,1,2)

# %%
K = np.array([[3.31666140e+03, 0.00000000e+00, 2.00701025e+03],
       [0.00000000e+00, 3.33904291e+03, 1.48586298e+03],
       [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])

# %%
pts1 = np.int32(pts1)
pts2 = np.int32(pts2)

# Estimate the essential matrix
E, mask = cv2.findEssentialMat(pts1,pts2,K)

# We select only inlier points
pts1_inliers = (pts1[mask.ravel()==1])
pts2_inliers = (pts2[mask.ravel()==1])

# %%
retval, R, t, mask = cv2.recoverPose(E, pts1_inliers, pts2_inliers, K)
print(R)
print(t)
# Out:
# [[ 0.98674438 -0.05149179  0.15389647]
#  [ 0.05062892  0.99867213  0.00952334]
#  [-0.15418249 -0.00160548  0.98804108]]
# [[-0.91775335]
#  [-0.12160059]
#  [ 0.37807683]]

# %%
# Take initial guess of intrinsic parameters through metadata
# !opensfm extract_metadata workspace/

# Detect features points 
# !opensfm detect_features workspace/


# Match feature points across images
# !opensfm match_features workspace/

# This creates "tracks" for the features. That is to say, if a feature in image 1 is matched with one in image 2,
# and in turn that one is matched with one in image 3, then it links the matches between 1 and 3. In this case, 
# it does not matter since we only have two images
# !opensfm create_tracks workspace/

# Calculates the essential matrix, the camera pose and the reconstructed feature points
# !opensfm reconstruct workspace/


# For visualization using Open3D
# !opensfm export_ply workspace/
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/bin/opensfm", line 34, in <module>
#     command.run(args)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/commands/extract_metadata.py", line 56, in run
#     data.save_camera_models(camera_models)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 470, in save_camera_models
#     with io.open_wt(self._camera_models_file()) as fout:
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/io.py", line 515, in open_wt
#     return io.open(path, 'w', encoding='utf-8')
# FileNotFoundError: [Errno 2] No such file or directory: 'workspace/camera_models.json'
# Traceback (most recent call last):
#   File "/opt/conda/bin/opensfm", line 34, in <module>
#     command.run(args)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/commands/detect_features.py", line 33, in run
#     with open(data.profile_log(), 'a') as fout:
# FileNotFoundError: [Errno 2] No such file or directory: 'workspace/profile.log'
# Traceback (most recent call last):
#   File "/opt/conda/bin/opensfm", line 34, in <module>
#     command.run(args)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/commands/match_features.py", line 29, in run
#     pairs_matches, preport = matching.match_images(data, images, images)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/matching.py", line 40, in match_images
#     ref_images, cand_images, exifs, data)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/pairs_selection.py", line 303, in match_candidates_from_metadata
#     data.invent_reference_lla()
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 438, in invent_reference_lla
#     self.save_reference_lla(reference)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 442, in save_reference_lla
#     with io.open_wt(self._reference_lla_path()) as fout:
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/io.py", line 515, in open_wt
#     return io.open(path, 'w', encoding='utf-8')
# FileNotFoundError: [Errno 2] No such file or directory: 'workspace/reference_lla.json'
# 2020-07-20 20:57:52,594 INFO: reading features
# 2020-07-20 20:57:52,594 DEBUG: Merging features onto tracks
# 2020-07-20 20:57:52,595 DEBUG: Good tracks: 0
# Traceback (most recent call last):
#   File "/opt/conda/bin/opensfm", line 34, in <module>
#     command.run(args)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/commands/create_tracks.py", line 30, in run
#     data.save_tracks_manager(tracks_manager)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 388, in save_tracks_manager
#     tracks_manager.write_to_file(self._tracks_manager_file(filename))
# RuntimeError: Can't write tracks manager file
# Traceback (most recent call last):
#   File "/opt/conda/bin/opensfm", line 34, in <module>
#     command.run(args)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/commands/reconstruct.py", line 21, in run
#     tracks_manager = data.load_tracks_manager()
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 382, in load_tracks_manager
#     return pysfm.TracksManager.instanciate_from_file(self._tracks_manager_file(filename))
# RuntimeError: Can't read tracks manager file
# Traceback (most recent call last):
#   File "/opt/conda/bin/opensfm", line 34, in <module>
#     command.run(args)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/commands/export_ply.py", line 38, in run
#     reconstructions = data.load_reconstruction()
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 398, in load_reconstruction
#     with io.open_rt(self._reconstruction_file(filename)) as fin:
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/io.py", line 520, in open_rt
#     return io.open(path, 'r', encoding='utf-8')
# FileNotFoundError: [Errno 2] No such file or directory: 'workspace/reconstruction.json'

# %%
# !opensfm undistort images/

# %%
# !opensfm compute_depthmaps images/
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/bin/opensfm", line 34, in <module>
#     command.run(args)
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/commands/compute_depthmaps.py", line 33, in run
#     reconstructions = udata.load_undistorted_reconstruction()
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 778, in load_undistorted_reconstruction
#     filename=os.path.join(self.subfolder, 'reconstruction.json'))
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/dataset.py", line 398, in load_reconstruction
#     with io.open_rt(self._reconstruction_file(filename)) as fin:
#   File "/opt/conda/lib/python3.7/site-packages/opensfm/io.py", line 520, in open_rt
#     return io.open(path, 'r', encoding='utf-8')
# FileNotFoundError: [Errno 2] No such file or directory: 'images/undistorted/reconstruction.json'
